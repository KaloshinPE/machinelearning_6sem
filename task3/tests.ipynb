# %%
import pandas as pd
import scipy as sc
import numpy as np
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor, ExtraTreesRegressor
from sklearn.model_selection import TimeSeriesSplit, train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 10)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
train = pd.read_csv("train.tsv")
test = pd.read_csv("test.tsv")
sample_submission = pd.read_csv("sample_submission.tsv")
train = train.sample(frac=0.1, random_state=42)

# %%
ohe = OneHotEncoder(sparse=False)
dummy_features = ohe.fit_transform(train['item_id'].values.reshape(-1, 1))
dummy_features = pd.DataFrame(dummy_features, columns=['good = ' + str(x) for x in range(dummy_features.shape[1])])
train.index = dummy_features.index
new_train = pd.concat([train, dummy_features], axis=1).drop(['item_id', 'Num'], axis=1)

# %%
dummy_features = ohe.fit_transform(new_train['week'].values.reshape(-1, 1))
dummy_features = pd.DataFrame(dummy_features, columns=['week = ' + str(x) for x in range(dummy_features.shape[1])])
new_train.index = dummy_features.index
new_train = pd.concat([new_train, dummy_features], axis=1).drop(['week'], axis=1)

# %%
dummy_features = ohe.fit_transform(new_train['year'].values.reshape(-1, 1))
dummy_features = pd.DataFrame(dummy_features, columns=['year = ' + str(x) for x in range(dummy_features.shape[1])])
new_train.index = dummy_features.index
new_train = pd.concat([new_train, dummy_features], axis=1).drop(['year'], axis=1)

# %%
def SMAPE(target, prediction):
    return 200*np.mean(np.abs(target-prediction)/(np.abs(target) + np.abs(prediction)))

# %%
def test_estimator(estimator):
    def do_stuff(X, y):
        tscv = TimeSeriesSplit(n_splits=3)
        score = []
        for train_index, test_index in tscv.split(X):
            estimator.fit(X[train_index], y[train_index])
            prediction = estimator.predict(X[test_index])
            score.append(SMAPE(y[test_index], prediction))
        print score
        return np.mean(score)
    return do_stuff(new_train.drop(['y'], axis=1).as_matrix(), new_train['y'].values), \
            do_stuff(train.drop(['y'], axis=1).as_matrix(), new_train['y'].values)

# %%
def SMAPE_scoring(estimator, X_test, y_test):
    tscv = TimeSeriesSplit(n_splits=3)
    score = []
    for train_index, test_index in tscv.split(X):
        estimator.fit(X[train_index], y[train_index])
        prediction = estimator.predict(X[test_index])
        score.append(SMAPE(y[test_index], prediction))
    ret = -np.mean(score)
    print -ret
    return ret

# %%
X, y = new_train.drop(['y'], axis=1).as_matrix(), new_train['y'].values

# %%
class sum_regressor:
    def __init__(self, weights):
        
        self.estimators = [RandomForestRegressor(n_estimators=weights[0]), 
                          GradientBoostingRegressor(n_estimators=weights[1], max_depth=5, loss='lad'), 
                          ExtraTreesRegressor(n_estimators=weights[2])]
        '''
        self.estimators = [GradientBoostingRegressor(loss='lad'),
                           RandomForestRegressor(),
                          ExtraTreesRegressor()]
        '''
    def fit(self, X, y):
        X_mine = np.copy(X)
        for est in self.estimators:
            est.fit(X_mine, y)
            if est!=self.estimators[-1]:
                np.c_[X_mine, est.predict(X_mine)]

    def predict(self, X):
        X_mine = np.copy(X)
        for est in self.estimators[:-1]:
            np.c_[X_mine, est.predict(X_mine)]
        return self.estimators[-1].predict(X_mine)

# %%
true_weights = None
score = 200
for w1 in range(10, 70, 10):
    for w2 in range(10, 70, 10):
        for w3 in range(10, 70, 10):
            print '\n', [w1, w2, w3]
            clf = sum_regressor(weights=[w1, w2, w3])
            new_score = test_estimator_onm(clf)
            if new_score < score:
                score = new_score
                true_weights = [w1, w2, w3]
            print new_score
# Out:
# [10, 10, 10]
# [28.719211308345443, 27.817681194801608, 26.683307810215574]
# 27.7400667711
#
# [10, 10, 20]
# [28.080849072696758, 26.977913021887357, 26.644713415849708]
# 27.2344918368
#
# [10, 10, 30]
# [28.049054645393916, 27.096063934608438, 26.27095379866784]
# 27.1386907929
#
# [10, 10, 40]
# [27.956607779923893, 26.643029386924709, 25.988416677569887]
# 26.8626846148
#
# [10, 10, 50]
# [28.107354896778002, 26.757534976120162, 26.553047310170331]
# 27.1393123944
#
# [10, 10, 60]
# [27.747783690299794, 26.823195608130156, 26.236724914274255]
# 26.9359014042
#
# [10, 20, 10]
# [29.265019657199471, 27.683493628037827, 27.27868062838844]
# 28.0757313045
#
# [10, 20, 20]
# [28.094297163474785, 27.181613415104717, 26.567540090031244]
# 27.2811502229
#
# [10, 20, 30]
# [27.720343285587717, 26.801496808634678, 26.379825229915539]
# 26.9672217747
#
# [10, 20, 40]
# [27.956222963891953, 26.66715038648378, 26.346602927792713]
# 26.9899920927
#
# [10, 20, 50]
# [27.88472069670684, 26.612375841005864, 26.091160398771979]
# 26.8627523122
#
# [10, 20, 60]
# [27.843910066987387, 26.490459761538009, 26.380339466557135]
# 26.9049030984
#
# [10, 30, 10]
# [28.542049659024205, 27.749986569231051, 27.416115111658527]
# 27.9027171133
#
# [10, 30, 20]
# [28.137502427673571, 27.052848397767583, 26.729113731740807]
# 27.3064881857
#
# [10, 30, 30]
# [28.18769714884311, 26.861685332779047, 26.588827370692218]
# 27.2127366174
#
# [10, 30, 40]
# [28.051439187106851, 26.573831522495539, 26.41865535691344]
# 27.0146420222
#
# [10, 30, 50]
# [27.926844716471738, 26.732362694912247, 25.958003045703492]
# 26.8724034857
#
# [10, 30, 60]
# [27.883841781655232, 26.67937958101772, 26.338074972276278]
# 26.9670987783
#
# [10, 40, 10]
# [28.932620243955693, 27.272428260170251, 27.138812069032969]
# 27.7812868577
#
# [10, 40, 20]
# [28.671595219207891, 26.81657520737873, 26.402347912075648]
# 27.2968394462
#
# [10, 40, 30]
# [28.081693537034841, 27.013752114563889, 26.413896313068967]
# 27.1697806549
#
# [10, 40, 40]
# [27.908000794029387, 26.770901733478897, 26.217537224560267]
# 26.9654799174
#
# [10, 40, 50]
# [27.86600375561294, 26.749035282219907, 26.114257645885143]
# 26.9097655612
#
# [10, 40, 60]
# [27.824904518404718, 26.540714568746289, 26.214814572823446]
# 26.8601445533
#
# [10, 50, 10]
# [29.10079971850789, 27.459925590199301, 27.175239410236447]
# 27.9119882396
#
# [10, 50, 20]
# [28.218854342145626, 27.147334191084521, 26.964015898717541]
# 27.4434014773
#
# [10, 50, 30]
# [28.109256463856642, 27.024547169454038, 26.425677086108241]
# 27.1864935731
#
# [10, 50, 40]
# [27.720961917858116, 26.783482571121841, 26.293882367349873]
# 26.9327756188
#
# [10, 50, 50]
# [28.129110681529411, 26.651134356893369, 26.336570714468948]
# 27.0389385843
#
# [10, 50, 60]
# [28.010590436200228, 26.629423295201406, 25.994598833589173]
# 26.8782041883
#
# [10, 60, 10]
# [28.596701769211112, 27.2333871634501, 27.132235020458729]
# 27.6541079844
#
# [10, 60, 20]
# [28.250511954682555, 27.034643992582623, 26.609886045996728]
# 27.2983473311
#
# [10, 60, 30]
# [28.184767669641843, 26.789485696839265, 26.270767422061354]
# 27.0816735962
#
# [10, 60, 40]
# [28.143060033127494, 26.918018420684181, 26.235656615576431]
# 27.0989116898
#
# [10, 60, 50]
# [27.933333303508935, 26.836028545549105, 26.226949482701194]
# 26.9987704439
#
# [10, 60, 60]
# [27.99630037658336, 26.71360483795165, 26.334433897667026]
# 27.0147797041
#
# [20, 10, 10]
# [28.936694685030627, 27.89162899518735, 27.557256402015895]
# 28.1285266941
#
# [20, 10, 20]
# [28.269511782527012, 26.833452000576969, 26.531767068218741]
# 27.2115769504
#
# [20, 10, 30]
# [27.996491085098533, 26.842669620844191, 26.559646251300968]
# 27.1329356524
#
# [20, 10, 40]
# [27.830042838115542, 26.894982659698968, 26.247838986928056]
# 26.9909548282
#
# [20, 10, 50]
# [27.932406110534817, 26.546611749718817, 26.214408393268947]
# 26.8978087512
#
# [20, 10, 60]
# [27.886431197679133, 26.847389668526773, 26.299631722026113]
# 27.0111508627
#
# [20, 20, 10]
# [28.877528654744861, 27.744010755620803, 27.005978942546239]
# 27.875839451
#
# [20, 20, 20]
# [28.119504467223926, 27.077952216737767, 26.631078960956412]
# 27.2761785483
#
# [20, 20, 30]
# [27.982095070067487, 26.875539199055826, 26.480228837858235]
# 27.1126210357
#
# [20, 20, 40]
# [27.830475809363776, 26.836826442583718, 26.039604327028066]
# 26.902302193
#
# [20, 20, 50]
# [27.661226229392799, 26.438239782614076, 26.31515297912329]
# 26.804872997
#
# [20, 20, 60]
# [27.952754542081415, 26.60889322019564, 26.164733988759046]
# 26.908793917
#
# [20, 30, 10]
# [29.271769428730828, 27.423959988074692, 27.236884641206117]
# 27.9775380193
#
# [20, 30, 20]
# [28.414608796324242, 27.083198062485387, 27.085259402798428]
# 27.5276887539
#
# [20, 30, 30]
# [27.949390120572389, 27.041464393433134, 26.167603303573816]
# 27.0528192725
#
# [20, 30, 40]
# [28.090110097842079, 26.669130970359671, 26.220198726486121]
# 26.9931465982
#
# [20, 30, 50]
# [28.049097069987145, 26.868269791640785, 26.32595892039793]
# 27.081108594
#
# [20, 30, 60]
# [27.974687068032594, 26.608404554939508, 26.211857878844587]
# 26.9316498339
#
# [20, 40, 10]
# [28.968818900895215, 27.332489573422446, 26.957965233278809]
# 27.7530912359
#
# [20, 40, 20]
# [28.291237442020119, 26.69071166982318, 26.146221245402362]
# 27.0427234524
#
# [20, 40, 30]
# [28.052831012799022, 26.946878283828863, 26.223185607606126]
# 27.0742983014
#
# [20, 40, 40]
# [27.921147839503242, 26.634103766052814, 26.460944714986042]
# 27.0053987735
#
# [20, 40, 50]
# [27.693122260777276, 26.720926201671048, 26.353220314942611]
# 26.9224229258
#
# [20, 40, 60]
# [27.920248405679889, 26.688942445219055, 26.144893258479158]
# 26.9180280365
#
# [20, 50, 10]
# [28.982125279786921, 27.746520062216895, 27.173764367990742]
# 27.9674699033
#
# [20, 50, 20]
# [28.53082058644074, 26.846115678261011, 26.445671686042672]
# 27.2742026502
#
# [20, 50, 30]
# [28.049339127932015, 27.017324128058405, 26.368192524012773]
# 27.1449519267
#
# [20, 50, 40]
# [27.749155113374425, 26.617612939913137, 26.308567777725862]
# 26.8917786103
#
# [20, 50, 50]
# [27.940404296301196, 26.825900536798869, 26.186041990404384]
# 26.9841156078
#
# [20, 50, 60]
# [27.89470334120691, 26.507391859139734, 26.198531821023895]
# 26.8668756738
#
# [20, 60, 10]
# [28.759823539382257, 28.052622732813244, 27.370572161502427]
# 28.0610061446
#
# [20, 60, 20]
# [28.372323397043758, 27.215341944453371, 26.616647658421357]
# 27.4014376666
#
# [20, 60, 30]
# [28.096355677179456, 26.844552922978693, 26.282028456084603]
# 27.0743123521
#
# [20, 60, 40]
# [27.907342517714902, 26.902786479331255, 26.389267974069774]
# 27.066465657
#
# [20, 60, 50]
# [27.948440843904393, 26.794506463120925, 26.099934355510161]
# 26.9476272208
#
# [20, 60, 60]
# [27.948239216200747, 26.706032749638116, 26.035481496289247]
# 26.8965844874
#
# [30, 10, 10]
# [28.799331818982637, 27.556909037375206, 27.306946774659036]
# 27.8877292103
#
# [30, 10, 20]
# [28.201195501025339, 26.878323023533873, 26.650411062221345]
# 27.2433098623
#
# [30, 10, 30]
# [28.005637485532159, 26.794249341011184, 26.272055369912866]
# 27.0239807322
#
# [30, 10, 40]
# [27.935155838797048, 26.498091192749936, 26.287678400259583]
# 26.9069751439
#
# [30, 10, 50]
# [27.953948639168114, 26.60954641188798, 26.208708866867088]
# 26.9240679726
#
# [30, 10, 60]
# [27.925793213076467, 26.87983671972485, 26.029744223326833]
# 26.9451247187
#
# [30, 20, 10]
# [28.354346038459568, 27.647534282046603, 27.095215556532064]
# 27.699031959
#
# [30, 20, 20]
# [28.428667539004689, 27.154510664467104, 26.741682293137092]
# 27.4416201655
#
# [30, 20, 30]
# [28.059356422210989, 27.057663812710214, 26.317790495245386]
# 27.1449369101
#
# [30, 20, 40]
# [27.830588351279328, 26.591536762809724, 26.292654740315403]
# 26.9049266181
#
# [30, 20, 50]
# [27.835873299604152, 26.877103306833423, 26.321551571886857]
# 27.0115093928
#
# [30, 20, 60]
# [27.699266471532052, 26.810815189391118, 26.155280827128241]
# 26.8884541627
#
# [30, 30, 10]
# [28.697827816990429, 27.304597323360841, 26.883270904591139]
# 27.6285653483
#
# [30, 30, 20]
# [28.353235638180159, 27.096286296017556, 27.172243022497721]
# 27.5405883189
#
# [30, 30, 30]
# [28.200570749396924, 26.657103858232471, 26.483446891657149]
# 27.1137071664
#
# [30, 30, 40]
# [27.920359828938601, 26.769917632616071, 26.070853980933201]
# 26.9203771475
#
# [30, 30, 50]
# [28.075229332529133, 26.522000179954432, 26.169343191464527]
# 26.9221909013
#
# [30, 30, 60]
# [27.86627231074208, 26.589260377536139, 26.197382595327355]
# 26.8843050945
#
# [30, 40, 10]
# [29.23935414000524, 28.00611540847348, 27.4688362458628]
# 28.2381019314
#
# [30, 40, 20]
# [28.491036359777201, 27.08882377102324, 26.254187745014047]
# 27.2780159586
#
# [30, 40, 30]
# [28.213531734226489, 26.406487824321211, 26.321496662429013]
# 26.980505407
#
# [30, 40, 40]
# [27.976507752205599, 26.522182750785213, 26.257752358780756]
# 26.9188142873
#
# [30, 40, 50]
# [27.830393442148686, 26.495262720906492, 26.034161628488228]
# 26.7866059305
#
# [30, 40, 60]
# [27.903552154030077, 26.572621456736954, 26.481054544406902]
# 26.9857427184
#
# [30, 50, 10]
# [28.523148941609001, 27.25901336481753, 27.130805250367224]
# 27.6376558523
#
# [30, 50, 20]
# [27.934030235900291, 27.094083520260771, 26.576487470440295]
# 27.2015337422
#
# [30, 50, 30]
# [27.977968300419686, 26.973088125519585, 26.293298301989658]
# 27.081451576
#
# [30, 50, 40]
# [28.073017616652084, 26.876064869455458, 26.211432202841234]
# 27.0535048963
#
# [30, 50, 50]
# [27.97819698788842, 26.843068039480102, 26.381989394956758]
# 27.0677514741
#
# [30, 50, 60]
# [27.958102577266448, 26.949292907974748, 26.258104175235331]
# 27.0551665535
#
# [30, 60, 10]
# [29.045724882299169, 27.510281383545436, 27.192457899102511]
# 27.9161547216
#
# [30, 60, 20]
# [28.235477588498036, 27.149865838660546, 27.019496893044554]
# 27.4682801067
#
# [30, 60, 30]
# [28.092069678721877, 26.707586334848948, 26.283889801574102]
# 27.027848605
#
# [30, 60, 40]
# [27.962821737240944, 26.798926277177664, 26.309742840096966]
# 27.0238302848
#
# [30, 60, 50]
# [28.060457710420661, 26.619759106228297, 26.175814546028697]
# 26.9520104542
#
# [30, 60, 60]
# [27.848200336656976, 26.799846317189186, 25.964275571315433]
# 26.8707740751
#
# [40, 10, 10]
# [28.688228677520204, 27.914134053315649, 26.8807191037046]
# 27.8276939448
#
# [40, 10, 20]
# [28.284771127878244, 26.957296536596729, 26.689333547670667]
# 27.3104670707
#
# [40, 10, 30]
# [27.974248542847473, 26.730659953954124, 26.321060799666562]
# 27.0086564322
#
# [40, 10, 40]
# [27.795749783076207, 26.652715456283431, 25.974243441604646]
# 26.8075695603
#
# [40, 10, 50]
# [27.888480297438882, 26.71079822989854, 25.954077823296345]
# 26.8511187835
#
# [40, 10, 60]
# [27.797602005438627, 26.618874291302131, 26.231868659146564]
# 26.882781652
#
# [40, 20, 10]
# [28.485558803894921, 27.724349975380864, 27.417492393645286]
# 27.875800391
#
# [40, 20, 20]
# [28.266097822084358, 27.18189922551716, 26.870765411872867]
# 27.4395874865
#
# [40, 20, 30]
# [28.396719572675323, 26.563499805035185, 26.457767860428461]
# 27.1393290794
#
# [40, 20, 40]
# [28.069213064792109, 26.608559610923916, 26.402783304328786]
# 27.0268519933
#
# [40, 20, 50]
# [27.985741078014808, 26.805748891755009, 26.284284694565731]
# 27.0252582214
#
# [40, 20, 60]
# [27.973314103919389, 26.700169954551345, 26.342886923568841]
# 27.005456994
#
# [40, 30, 10]
# [29.09256543836247, 27.316040726110003, 26.942433329886473]
# 27.7836798315
#
# [40, 30, 20]
# [28.060240459288099, 27.14763891426654, 26.668132391178652]
# 27.2920039216
#
# [40, 30, 30]
# [27.96630272518389, 26.951420986258313, 26.34464409127893]
# 27.0874559342
#
# [40, 30, 40]
# [28.163625408604599, 26.660188272882873, 26.39678499525737]
# 27.0735328922
#
# [40, 30, 50]
# [27.681951045385368, 26.701926033956958, 26.177348674448137]
# 26.8537419179
#
# [40, 30, 60]
# [27.893974126548571, 26.601563220486106, 26.278297642743802]
# 26.9246116633
#
# [40, 40, 10]
# [28.764264031639875, 27.837216571377787, 27.058286323169185]
# 27.8865889754
#
# [40, 40, 20]
# [28.116816476108617, 26.693875865923012, 26.553610126503163]
# 27.1214341562
#
# [40, 40, 30]
# [28.018858505958239, 26.810309951229645, 26.447794500249177]
# 27.0923209858
#
# [40, 40, 40]
# [27.869073875847079, 26.855551758110703, 26.267378706464019]
# 26.9973347801
#
# [40, 40, 50]
# [27.736670279974003, 26.692741301155376, 26.068351732871541]
# 26.8325877713
#
# [40, 40, 60]
# [27.715281400999135, 26.644016000871311, 26.255950351815887]
# 26.8717492512
#
# [40, 50, 10]
# [28.876882621358003, 27.303882706617106, 27.312382527530698]
# 27.8310492852
#
# [40, 50, 20]
# [28.32290623718287, 26.966866304598963, 26.786306573285639]
# 27.3586930384
#
# [40, 50, 30]
# [27.94561929517851, 26.804353879621818, 26.057279629461334]
# 26.9357509348
#
# [40, 50, 40]
# [27.784417055753082, 26.831508349039829, 26.379046738515381]
# 26.9983240478
#
# [40, 50, 50]
# [28.001811117119672, 26.595696214050307, 26.055264741838695]
# 26.8842573577
#
# [40, 50, 60]
# [27.959986111896502, 26.678503571512419, 26.235848959176796]
# 26.9581128809
#
# [40, 60, 10]
# [29.131493334270253, 27.580731318068953, 26.957323421987567]
# 27.8898493581
#
# [40, 60, 20]
# [28.127153020720375, 26.926217092336685, 26.580100402149]
# 27.2111568384
#
# [40, 60, 30]
# [27.922089048964178, 26.851421216133541, 26.302330770523692]
# 27.0252803452
#
# [40, 60, 40]
# [28.120207584020612, 26.824882888041486, 26.310711754383302]
# 27.0852674088
#
# [40, 60, 50]
# [27.882600598206508, 26.676671137912187, 26.201632276263531]
# 26.9203013375
#
# [40, 60, 60]
# [27.679954819479963, 26.821242784769904, 26.226440980233473]
# 26.9092128615
#
# [50, 10, 10]
# [28.48872542711559, 27.744942301425528, 27.647303515035947]
# 27.9603237479
#
# [50, 10, 20]
# [28.367156848583342, 26.838296771407339, 26.34982157071164]
# 27.1850917302
#
# [50, 10, 30]
# [28.342688235638914, 26.828382037907271, 26.485645722761049]
# 27.2189053321
#
# [50, 10, 40]
# [27.982031412221371, 26.561421892850124, 26.286990844963338]
# 26.9434813833
#
# [50, 10, 50]
# [28.097029556777166, 26.719103401978973, 26.232481663762787]
# 27.0162048742
#
# [50, 10, 60]
# [27.927354212224976, 26.657558205668895, 26.090696698897077]
# 26.8918697056
#
# [50, 20, 10]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-199-b3c4abcf1659> in <module>()
#       6             print '\n', [w1, w2, w3]
#       7             clf = sum_regressor(weights=[w1, w2, w3])
# ----> 8             new_score = test_estimator_onm(clf)
#       9             if new_score < score:
#      10                 score = new_score
#
# <ipython-input-37-154ff752804d> in test_estimator_onm(estimator)
#       9         print score
#      10         return np.mean(score)
# ---> 11     return do_stuff(new_train.drop(['y'], axis=1).as_matrix(), new_train['y'].values)
#
# <ipython-input-37-154ff752804d> in do_stuff(X, y)
#       4         score = []
#       5         for train_index, test_index in tscv.split(X):
# ----> 6             estimator.fit(X[train_index], y[train_index])
#       7             prediction = estimator.predict(X[test_index])
#       8             score.append(SMAPE(y[test_index], prediction))
#
# <ipython-input-198-442bf05af9eb> in fit(self, X, y)
#      13         X_mine = np.copy(X)
#      14         for est in self.estimators:
# ---> 15             est.fit(X_mine, y)
#      16             if est!=self.estimators[-1]:
#      17                 np.c_[X_mine, est.predict(X_mine)]
#
# /home/pavel/anaconda2/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in fit(self, X, y, sample_weight)
#     324                     t, self, X, y, sample_weight, i, len(trees),
#     325                     verbose=self.verbose, class_weight=self.class_weight)
# --> 326                 for i, t in enumerate(trees))
#     327
#     328             # Collect newly grown trees
#
# /home/pavel/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /home/pavel/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# /home/pavel/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# /home/pavel/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# /home/pavel/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# /home/pavel/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /home/pavel/anaconda2/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     118             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     119
# --> 120         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     121     else:
#     122         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /home/pavel/anaconda2/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1027             sample_weight=sample_weight,
#    1028             check_input=check_input,
# -> 1029             X_idx_sorted=X_idx_sorted)
#    1030         return self
#    1031
#
# /home/pavel/anaconda2/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     348                                            self.min_impurity_split)
#     349
# --> 350         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     351
#     352         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
test_estimator_onm(sum_regressor())
# Out:
# [27.799928501491177, 26.517960228790638, 26.130408874123624]
# 26.816099201468479
